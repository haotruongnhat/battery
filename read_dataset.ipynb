# %%
data_path = r".\dataset\ecg\labeled\train\chfdb_chf13_45590.pkl"

# %%
import pandas as pd

# %%
import numpy as np

# %%
import pickle

with open(data_path, 'rb') as f:
    data = pickle.load(f)

# %%
import matplotlib.pyplot as plt

# %%
test_path = r".\dataset\ecg\labeled\test\chfdb_chf13_45590.pkl"

# %%
with open(test_path, 'rb') as f:
    test_data = pickle.load(f)

# %%
predict_path = r".\result\ecg\chfdb_chf13_45590\Nstep_predictions.pkl"

# %%
with open(predict_path, 'rb') as f:
    predict_data = pickle.load(f)

# %%
plt.plot(test_data)

# %%
plt.plot(np.array(test_data)[:, 0])
plt.plot(predict_data[0])

# %%
plt.plot(np.array(test_data)[:,1])
plt.plot(predict_data[1], "--")
